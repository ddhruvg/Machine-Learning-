# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from sklearn import tree
import sklearn
from sklearn.ensemble import RandomForestClassifier
data_train  = pd.read_csv('data/q1/train.csv')
data_test = pd.read_csv('data/q1/test.csv')
data_validation = pd.read_csv('data/q1/validation.csv')
categorical_cols = data_train.select_dtypes(include='object').columns.tolist()
data_train = pd.get_dummies(data_train, columns=categorical_cols ,  dtype=int)
data_validation = pd.get_dummies(data_validation, columns=categorical_cols ,  dtype=int)
data_test = pd.get_dummies(data_test, columns=categorical_cols ,  dtype=int)
data_test = data_test.reindex(columns=data_train.columns, fill_value=0)
data_validation = data_validation.reindex(columns=data_train.columns, fill_value=0)

# %%
clf = sklearn.ensemble.RandomForestClassifier

# %%
n_param = [50,150,250,350]
mx_feature = [0.1,0.3,0.5,0.7]
split_values = [2,4,6,8]

# %%
res = []
for n in n_param:
    for mx in mx_feature:
        for sp in split_values:
            clf =  RandomForestClassifier(n_estimators=n, max_features=mx, min_samples_split=sp, criterion='entropy')
            clf.fit(data_train.drop('result', axis=1), data_train['result'])
            train_acc = clf.score(data_train.drop('result', axis=1), data_train['result'])*100
            test_acc = clf.score(data_test.drop('result', axis=1), data_test['result'])*100
            val_acc = clf.score(data_validation.drop('result', axis=1), data_validation['result'])*100

            res.append([n,mx,sp,train_acc,test_acc,val_acc])
            print(f"n_estimators: {n}, max_features: {mx}, min_samples_split: {sp} => Train Acc: {train_acc} , Test Acc: {test_acc} , Val Acc: {val_acc}")
# Out:
# n_estimators: 50, max_features: 0.1, min_samples_split: 2 => Train Acc: 99.98722371278906 , Test Acc: 66.59772492244053 , Val Acc: 65.63218390804599
# n_estimators: 50, max_features: 0.1, min_samples_split: 4 => Train Acc: 99.31008049060944 , Test Acc: 66.80455015511893 , Val Acc: 66.20689655172414
# n_estimators: 50, max_features: 0.1, min_samples_split: 6 => Train Acc: 96.8825859205315 , Test Acc: 67.52843846949328 , Val Acc: 69.42528735632185
# n_estimators: 50, max_features: 0.1, min_samples_split: 8 => Train Acc: 95.40053660406286 , Test Acc: 67.83867631851086 , Val Acc: 69.3103448275862
# n_estimators: 50, max_features: 0.3, min_samples_split: 2 => Train Acc: 99.98722371278906 , Test Acc: 68.56256463288521 , Val Acc: 67.58620689655173
# n_estimators: 50, max_features: 0.3, min_samples_split: 4 => Train Acc: 99.70614539414846 , Test Acc: 67.3216132368149 , Val Acc: 69.08045977011494
# n_estimators: 50, max_features: 0.3, min_samples_split: 6 => Train Acc: 98.97789702312508 , Test Acc: 67.94208893485005 , Val Acc: 69.08045977011494
# n_estimators: 50, max_features: 0.3, min_samples_split: 8 => Train Acc: 97.70026830203143 , Test Acc: 68.35573940020683 , Val Acc: 69.19540229885057
# n_estimators: 50, max_features: 0.5, min_samples_split: 2 => Train Acc: 100.0 , Test Acc: 69.28645294725956 , Val Acc: 68.73563218390805
# n_estimators: 50, max_features: 0.5, min_samples_split: 4 => Train Acc: 99.79557940462502 , Test Acc: 70.01034126163393 , Val Acc: 69.77011494252874
# n_estimators: 50, max_features: 0.5, min_samples_split: 6 => Train Acc: 99.18231761850006 , Test Acc: 69.28645294725956 , Val Acc: 69.08045977011494
# n_estimators: 50, max_features: 0.5, min_samples_split: 8 => Train Acc: 98.50517439632043 , Test Acc: 67.94208893485005 , Val Acc: 70.11494252873564
# n_estimators: 50, max_features: 0.7, min_samples_split: 2 => Train Acc: 99.91056598952345 , Test Acc: 69.80351602895554 , Val Acc: 68.96551724137932
# n_estimators: 50, max_features: 0.7, min_samples_split: 4 => Train Acc: 99.89778970231251 , Test Acc: 68.56256463288521 , Val Acc: 68.27586206896552
# n_estimators: 50, max_features: 0.7, min_samples_split: 6 => Train Acc: 99.37396192666411 , Test Acc: 68.976215098242 , Val Acc: 69.6551724137931
# n_estimators: 50, max_features: 0.7, min_samples_split: 8 => Train Acc: 98.46684553468762 , Test Acc: 69.90692864529473 , Val Acc: 70.0
# n_estimators: 150, max_features: 0.1, min_samples_split: 2 => Train Acc: 100.0 , Test Acc: 68.14891416752845 , Val Acc: 68.04597701149426
# n_estimators: 150, max_features: 0.1, min_samples_split: 4 => Train Acc: 99.36118563945317 , Test Acc: 67.52843846949328 , Val Acc: 70.11494252873564
# n_estimators: 150, max_features: 0.1, min_samples_split: 6 => Train Acc: 97.73859716366424 , Test Acc: 68.35573940020683 , Val Acc: 68.73563218390805
# n_estimators: 150, max_features: 0.1, min_samples_split: 8 => Train Acc: 95.93714066692219 , Test Acc: 68.35573940020683 , Val Acc: 69.77011494252874
# n_estimators: 150, max_features: 0.3, min_samples_split: 2 => Train Acc: 100.0 , Test Acc: 67.94208893485005 , Val Acc: 68.85057471264368
# n_estimators: 150, max_features: 0.3, min_samples_split: 4 => Train Acc: 99.94889485115625 , Test Acc: 68.976215098242 , Val Acc: 68.04597701149426
# n_estimators: 150, max_features: 0.3, min_samples_split: 6 => Train Acc: 99.38673821387505 , Test Acc: 69.49327817993796 , Val Acc: 70.0
# n_estimators: 150, max_features: 0.3, min_samples_split: 8 => Train Acc: 98.42851667305482 , Test Acc: 68.14891416752845 , Val Acc: 70.91954022988506
# n_estimators: 150, max_features: 0.5, min_samples_split: 2 => Train Acc: 100.0 , Test Acc: 67.63185108583247 , Val Acc: 68.73563218390805
# n_estimators: 150, max_features: 0.5, min_samples_split: 4 => Train Acc: 99.9616711383672 , Test Acc: 67.63185108583247 , Val Acc: 68.85057471264368
# n_estimators: 150, max_features: 0.5, min_samples_split: 6 => Train Acc: 99.60393509646097 , Test Acc: 68.976215098242 , Val Acc: 70.0
# n_estimators: 150, max_features: 0.5, min_samples_split: 8 => Train Acc: 98.73514756611729 , Test Acc: 70.01034126163393 , Val Acc: 69.6551724137931
# n_estimators: 150, max_features: 0.7, min_samples_split: 2 => Train Acc: 100.0 , Test Acc: 68.45915201654603 , Val Acc: 69.3103448275862
# n_estimators: 150, max_features: 0.7, min_samples_split: 4 => Train Acc: 100.0 , Test Acc: 68.7693898655636 , Val Acc: 70.22988505747126
# n_estimators: 150, max_features: 0.7, min_samples_split: 6 => Train Acc: 99.69336910693752 , Test Acc: 68.14891416752845 , Val Acc: 69.77011494252874
# n_estimators: 150, max_features: 0.7, min_samples_split: 8 => Train Acc: 98.97789702312508 , Test Acc: 68.976215098242 , Val Acc: 70.57471264367817
# n_estimators: 250, max_features: 0.1, min_samples_split: 2 => Train Acc: 100.0 , Test Acc: 67.73526370217166 , Val Acc: 68.04597701149426
# n_estimators: 250, max_features: 0.1, min_samples_split: 4 => Train Acc: 99.52727737319535 , Test Acc: 68.14891416752845 , Val Acc: 68.96551724137932
# n_estimators: 250, max_features: 0.1, min_samples_split: 6 => Train Acc: 97.96857033346109 , Test Acc: 68.976215098242 , Val Acc: 70.22988505747126
# n_estimators: 250, max_features: 0.1, min_samples_split: 8 => Train Acc: 96.2182189855628 , Test Acc: 69.18304033092038 , Val Acc: 70.0
# n_estimators: 250, max_features: 0.3, min_samples_split: 2 => Train Acc: 100.0 , Test Acc: 68.45915201654603 , Val Acc: 68.73563218390805
# n_estimators: 250, max_features: 0.3, min_samples_split: 4 => Train Acc: 99.93611856394531 , Test Acc: 68.56256463288521 , Val Acc: 68.96551724137932
# n_estimators: 250, max_features: 0.3, min_samples_split: 6 => Train Acc: 99.52727737319535 , Test Acc: 69.07962771458118 , Val Acc: 69.88505747126436
# n_estimators: 250, max_features: 0.3, min_samples_split: 8 => Train Acc: 98.42851667305482 , Test Acc: 69.18304033092038 , Val Acc: 69.3103448275862
# n_estimators: 250, max_features: 0.5, min_samples_split: 2 => Train Acc: 100.0 , Test Acc: 68.45915201654603 , Val Acc: 70.0
# n_estimators: 250, max_features: 0.5, min_samples_split: 4 => Train Acc: 100.0 , Test Acc: 69.18304033092038 , Val Acc: 70.0
# n_estimators: 250, max_features: 0.5, min_samples_split: 6 => Train Acc: 99.65504024530472 , Test Acc: 68.35573940020683 , Val Acc: 69.88505747126436
# n_estimators: 250, max_features: 0.5, min_samples_split: 8 => Train Acc: 98.7734764277501 , Test Acc: 68.976215098242 , Val Acc: 70.11494252873564
# n_estimators: 250, max_features: 0.7, min_samples_split: 2 => Train Acc: 100.0 , Test Acc: 69.07962771458118 , Val Acc: 70.6896551724138
# n_estimators: 250, max_features: 0.7, min_samples_split: 4 => Train Acc: 100.0 , Test Acc: 68.25232678386763 , Val Acc: 69.54022988505747
# n_estimators: 250, max_features: 0.7, min_samples_split: 6 => Train Acc: 99.66781653251566 , Test Acc: 68.35573940020683 , Val Acc: 69.54022988505747
# n_estimators: 250, max_features: 0.7, min_samples_split: 8 => Train Acc: 99.05455474639069 , Test Acc: 69.28645294725956 , Val Acc: 69.54022988505747
# n_estimators: 350, max_features: 0.1, min_samples_split: 2 => Train Acc: 100.0 , Test Acc: 66.28748707342295 , Val Acc: 67.1264367816092
# n_estimators: 350, max_features: 0.1, min_samples_split: 4 => Train Acc: 99.64226395809378 , Test Acc: 68.976215098242 , Val Acc: 69.19540229885057
# n_estimators: 350, max_features: 0.1, min_samples_split: 6 => Train Acc: 98.04522805672671 , Test Acc: 67.52843846949328 , Val Acc: 70.6896551724138
# n_estimators: 350, max_features: 0.1, min_samples_split: 8 => Train Acc: 96.29487670882841 , Test Acc: 68.25232678386763 , Val Acc: 70.11494252873564
# n_estimators: 350, max_features: 0.3, min_samples_split: 2 => Train Acc: 100.0 , Test Acc: 67.94208893485005 , Val Acc: 68.85057471264368
# n_estimators: 350, max_features: 0.3, min_samples_split: 4 => Train Acc: 100.0 , Test Acc: 68.45915201654603 , Val Acc: 68.96551724137932
# n_estimators: 350, max_features: 0.3, min_samples_split: 6 => Train Acc: 99.45061964992973 , Test Acc: 68.14891416752845 , Val Acc: 69.3103448275862
# n_estimators: 350, max_features: 0.3, min_samples_split: 8 => Train Acc: 98.5307269707423 , Test Acc: 68.25232678386763 , Val Acc: 70.22988505747126
# n_estimators: 350, max_features: 0.5, min_samples_split: 2 => Train Acc: 100.0 , Test Acc: 69.18304033092038 , Val Acc: 69.77011494252874
# n_estimators: 350, max_features: 0.5, min_samples_split: 4 => Train Acc: 100.0 , Test Acc: 68.7693898655636 , Val Acc: 70.11494252873564
# n_estimators: 350, max_features: 0.5, min_samples_split: 6 => Train Acc: 99.66781653251566 , Test Acc: 68.7693898655636 , Val Acc: 70.57471264367817
# n_estimators: 350, max_features: 0.5, min_samples_split: 8 => Train Acc: 98.90123929985945 , Test Acc: 69.49327817993796 , Val Acc: 70.0
# n_estimators: 350, max_features: 0.7, min_samples_split: 2 => Train Acc: 100.0 , Test Acc: 69.18304033092038 , Val Acc: 69.88505747126436
# n_estimators: 350, max_features: 0.7, min_samples_split: 4 => Train Acc: 100.0 , Test Acc: 68.66597724922441 , Val Acc: 69.19540229885057
# n_estimators: 350, max_features: 0.7, min_samples_split: 6 => Train Acc: 99.80835569183594 , Test Acc: 69.18304033092038 , Val Acc: 70.22988505747126
# n_estimators: 350, max_features: 0.7, min_samples_split: 8 => Train Acc: 99.11843618244538 , Test Acc: 69.18304033092038 , Val Acc: 70.11494252873564

# %%
best = sorted(res, key=lambda x: x[5], reverse=True)[0]

# %%
print("Best Hyperparameters:")
print(f"n_estimators: {best[0]}, max_features: {best[1]}, min_samples_split: {best[2]} => Train Acc: {best[3]} , Test Acc: {best[4]} , Val Acc: {best[5]}")
# Out:
# Best Hyperparameters:
# n_estimators: 150, max_features: 0.3, min_samples_split: 8 => Train Acc: 98.42851667305482 , Test Acc: 68.14891416752845 , Val Acc: 70.91954022988506

# %%
#out of the bag accuracy for best model 
clf =  RandomForestClassifier(n_estimators=best[0], max_features=best[1], min_samples_split=best[2], criterion='entropy', oob_score=True)
clf.fit(data_train.drop('result', axis=1), data_train['result'])
print(f"OOB Accuracy: {clf.oob_score_*100} %")
# Out:
# OOB Accuracy: 70.30790852178357 %
